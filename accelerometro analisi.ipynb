# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dati = pd.read_csv('dati2.csv')

# %%
dati
# Out:
#           time     gFx     gFy     gFz    TgF
# 0     0.006370  0.0029 -0.0037  0.9985  1.010
# 1     0.007056  0.0042 -0.0012  0.9971  1.009
# 2     0.007700  0.0015 -0.0010  0.9932  1.005
# 3     0.008473  0.0012 -0.0005  0.9968  1.009
# 4     0.008955  0.0027  0.0000  0.9976  1.009
# ...        ...     ...     ...     ...    ...
# 3536  8.460549 -0.0002 -0.0029  0.9958  1.008
# 3537  8.463052  0.0005 -0.0020  0.9968  1.009
# 3538  8.465529  0.0005 -0.0024  0.9985  1.010
# 3539  8.468101  0.0015 -0.0017  0.9966  1.008
# 3540  8.470873  0.0000 -0.0029  0.9968  1.009
#
# [3541 rows x 5 columns]

# %%
plt.plot(dati.time,dati.TgF)
plt.show()

# %%
fig, axs = plt.subplots(3, 1,figsize=(10,10))

fig.suptitle('Accelerometro')

axs[0].plot(dati.time, dati.gFx, 'r')
axs[0].title.set_text('Asse X')

axs[1].plot(dati.time, dati.gFy, 'g')
axs[1].title.set_text('Asse Y')

axs[2].plot(dati.time, dati.gFz, 'b')
axs[2].title.set_text('Asse Z')


for grafico in axs:
    grafico.grid()

fig.savefig('Accelerometro.jpg')
